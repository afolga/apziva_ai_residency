# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report, f1_score

# %%
data=pd.read_csv("C:\\Users\\agnes\\Documents\\apziva_ai_residency\\project2\\data\\term-deposit-marketing-2020.csv")

# %%
data['y'].value_counts()
# Out:
# no     37104
# yes     2896
# Name: y, dtype: int64

# %%
data['job']=data['job'].astype('category')
data['marital']=data['marital'].astype('category')
data['education']=data['education'].astype('category')
data['default']=data['default'].astype('category')
data['housing']=data['housing'].astype('category')
data['loan']=data['loan'].astype('category')
data['contact']=data['contact'].astype('category')
data['month']=data['month'].astype('category')
data['y']=data['y'].astype('category')
cat_columns = data.select_dtypes(['category']).columns
data[cat_columns] = data[cat_columns].apply(lambda x: x.cat.codes)

# %%
matrix=data.corr()
print(matrix)
# Out:
#                 age       job   marital  education   default   balance  \
# age        1.000000 -0.019719 -0.386716  -0.091083 -0.014857  0.081517
# job       -0.019719  1.000000  0.051588   0.174336 -0.004977  0.015187
# marital   -0.386716  0.051588  1.000000   0.095899 -0.004595  0.008542
# education -0.091083  0.174336  0.095899   1.000000 -0.006647  0.066592
# default   -0.014857 -0.004977 -0.004595  -0.006647  1.000000 -0.070069
# balance    0.081517  0.015187  0.008542   0.066592 -0.070069  1.000000
# housing   -0.179606 -0.114148  0.004453  -0.083699 -0.019229 -0.049946
# loan       0.000041 -0.024220 -0.042975  -0.043702  0.075006 -0.080596
# contact    0.041114 -0.077812 -0.029242  -0.096023  0.006881 -0.011681
# day       -0.011689  0.028441  0.000099   0.036206  0.006287  0.011662
# month     -0.063437 -0.106735 -0.006779  -0.066100  0.013660  0.023718
# duration  -0.036270 -0.002445  0.015772   0.001828 -0.008597  0.014072
# campaign   0.016204  0.013914 -0.001259   0.016562  0.012135 -0.008137
# y         -0.020273  0.017250  0.030229   0.037585 -0.006559  0.030232
#
#             housing      loan   contact       day     month  duration  \
# age       -0.179606  0.000041  0.041114 -0.011689 -0.063437 -0.036270
# job       -0.114148 -0.024220 -0.077812  0.028441 -0.106735 -0.002445
# marital    0.004453 -0.042975 -0.029242  0.000099 -0.006779  0.015772
# education -0.083699 -0.043702 -0.096023  0.036206 -0.066100  0.001828
# default   -0.019229  0.075006  0.006881  0.006287  0.013660 -0.008597
# balance   -0.049946 -0.080596 -0.011681  0.011662  0.023718  0.014072
# housing    1.000000  0.004266  0.164406 -0.050622  0.327019  0.022455
# loan       0.004266  1.000000 -0.030899  0.005838  0.027403 -0.003952
# contact    0.164406 -0.030899  1.000000 -0.045535  0.410025 -0.008292
# day       -0.050622  0.005838 -0.045535  1.000000 -0.002587 -0.032983
# month      0.327019  0.027403  0.410025 -0.002587  1.000000  0.005171
# duration   0.022455 -0.003952 -0.008292 -0.032983  0.005171  1.000000
# campaign  -0.054823  0.000582  0.003019  0.165429 -0.118326 -0.088387
# y         -0.054336 -0.031029 -0.089626 -0.006420 -0.046141  0.461169
#
#            campaign         y
# age        0.016204 -0.020273
# job        0.013914  0.017250
# marital   -0.001259  0.030229
# education  0.016562  0.037585
# default    0.012135 -0.006559
# balance   -0.008137  0.030232
# housing   -0.054823 -0.054336
# loan       0.000582 -0.031029
# contact    0.003019 -0.089626
# day        0.165429 -0.006420
# month     -0.118326 -0.046141
# duration  -0.088387  0.461169
# campaign   1.000000 -0.040350
# y         -0.040350  1.000000

# %%
x= data[['age', 'job','marital','education','balance','housing','day','month','duration','campaign']]
y=data[['y']]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x, y, test_size=0.2, random_state=0)

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train.values.ravel())
predictions=lr.predict(x_test)
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      7425
#            1       0.57      0.21      0.31       575
#
#     accuracy                           0.93      8000
#    macro avg       0.76      0.60      0.64      8000
# weighted avg       0.92      0.93      0.92      8000
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from imblearn.under_sampling import RandomUnderSampler  

under_sampler = RandomUnderSampler()
X_res, y_res = under_sampler.fit_resample(x, y)

# %%
x_train_res, y_train_res=under_sampler.fit_resample(x_train,y_train)

# %%
lr2=LogisticRegression()
lr2.fit(x_train_res, y_train_res.values.ravel())
predictions=lr2.predict(x_test)
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.83      0.90      7425
#            1       0.26      0.76      0.39       575
#
#     accuracy                           0.83      8000
#    macro avg       0.62      0.80      0.64      8000
# weighted avg       0.93      0.83      0.86      8000
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
f1_score(y_test,predictions)
# Out:
# 0.3871252204585538

# %%
## adding grid search 
parameters = [ {'max_depth': [2, 4, 6, 10], 'min_samples_leaf': [2, 3, 4, 5, 7], 'min_samples_split' : [2, 3, 4, 5]}]

# %%
#
LR = LogisticRegression()
LRparam_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
    'penalty': ['l1', 'l2'],
     'max_iter': list(range(100,10000,100)),
    'solver': ['newton-cg', 'lbfgs', 'liblinear']
}
#search = RandomizedSearchCV(model, space, n_iter=100000, scoring='f1', n_jobs=-1, cv=cv, random_state=1)
lr_grid={'C': 0.001, 'penalty': 'l2', 'solver': 'lbfgs'}
grid={"C":np.logspace(-3,3,7), "penalty":["l1","l2"]}s

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score, make_scorer

f1 = make_scorer(f1_score , average='macro')

LR_search = GridSearchCV(LR, param_grid=grid, refit = True, verbose = 3, cv=5,scoring=f1)

#result = search.fit(x, y)

# %%
LR_search.fit(x_train_res, y_train_res.values.ravel())
# Out:
# Fitting 5 folds for each of 4158 candidates, totalling 20790 fits
# [CV 1/5] END C=0.001, max_iter=100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=100, penalty=l1, solver=liblinear;, score=0.797 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=100, penalty=l1, solver=liblinear;, score=0.783 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=100, penalty=l1, solver=liblinear;, score=0.808 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=100, penalty=l1, solver=liblinear;, score=0.798 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=100, penalty=l1, solver=liblinear;, score=0.800 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg;, score=0.801 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg;, score=0.797 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg;, score=0.816 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg;, score=0.820 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs;, score=0.800 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs;, score=0.793 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs;, score=0.803 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs;, score=0.813 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs;, score=0.804 total time=   0.0s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5] END C=0.001, max_iter=100, penalty=l2, solver=liblinear;, score=0.802 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=100, penalty=l2, solver=liblinear;, score=0.792 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=100, penalty=l2, solver=liblinear;, score=0.807 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=100, penalty=l2, solver=liblinear;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=100, penalty=l2, solver=liblinear;, score=0.803 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=200, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=200, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=200, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=200, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=200, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=200, penalty=l1, solver=liblinear;, score=0.797 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=200, penalty=l1, solver=liblinear;, score=0.783 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=200, penalty=l1, solver=liblinear;, score=0.808 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=200, penalty=l1, solver=liblinear;, score=0.798 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=200, penalty=l1, solver=liblinear;, score=0.800 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg;, score=0.801 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg;, score=0.797 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg;, score=0.816 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg;, score=0.820 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs;, score=0.800 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs;, score=0.790 total time=   0.0s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs;, score=0.808 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs;, score=0.811 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs;, score=0.805 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=200, penalty=l2, solver=liblinear;, score=0.802 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=200, penalty=l2, solver=liblinear;, score=0.792 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=200, penalty=l2, solver=liblinear;, score=0.807 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=200, penalty=l2, solver=liblinear;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=200, penalty=l2, solver=liblinear;, score=0.803 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=300, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=300, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=300, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=300, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=300, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=300, penalty=l1, solver=liblinear;, score=0.797 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=300, penalty=l1, solver=liblinear;, score=0.783 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=300, penalty=l1, solver=liblinear;, score=0.808 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=300, penalty=l1, solver=liblinear;, score=0.798 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=300, penalty=l1, solver=liblinear;, score=0.800 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg;, score=0.801 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg;, score=0.797 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg;, score=0.816 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg;, score=0.820 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=300, penalty=l2, solver=lbfgs;, score=0.799 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=300, penalty=l2, solver=lbfgs;, score=0.792 total time=   0.0s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5] END C=0.001, max_iter=300, penalty=l2, solver=lbfgs;, score=0.818 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=300, penalty=l2, solver=lbfgs;, score=0.814 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=300, penalty=l2, solver=lbfgs;, score=0.805 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=300, penalty=l2, solver=liblinear;, score=0.802 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=300, penalty=l2, solver=liblinear;, score=0.792 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=300, penalty=l2, solver=liblinear;, score=0.807 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=300, penalty=l2, solver=liblinear;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=300, penalty=l2, solver=liblinear;, score=0.803 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=400, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=400, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=400, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=400, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=400, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=400, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=400, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=400, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=400, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=400, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=400, penalty=l1, solver=liblinear;, score=0.797 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=400, penalty=l1, solver=liblinear;, score=0.783 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=400, penalty=l1, solver=liblinear;, score=0.808 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=400, penalty=l1, solver=liblinear;, score=0.798 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=400, penalty=l1, solver=liblinear;, score=0.800 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=400, penalty=l2, solver=newton-cg;, score=0.801 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=400, penalty=l2, solver=newton-cg;, score=0.797 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=400, penalty=l2, solver=newton-cg;, score=0.816 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=400, penalty=l2, solver=newton-cg;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=400, penalty=l2, solver=newton-cg;, score=0.820 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=400, penalty=l2, solver=lbfgs;, score=0.800 total time=   0.0s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END C=0.001, max_iter=400, penalty=l2, solver=lbfgs;, score=0.793 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=400, penalty=l2, solver=lbfgs;, score=0.809 total time=   0.0s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END C=0.001, max_iter=400, penalty=l2, solver=lbfgs;, score=0.811 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=400, penalty=l2, solver=lbfgs;, score=0.805 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=400, penalty=l2, solver=liblinear;, score=0.802 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=400, penalty=l2, solver=liblinear;, score=0.792 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=400, penalty=l2, solver=liblinear;, score=0.807 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=400, penalty=l2, solver=liblinear;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=400, penalty=l2, solver=liblinear;, score=0.803 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=500, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=500, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=500, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=500, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=500, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=500, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=500, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=500, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=500, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=500, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=500, penalty=l1, solver=liblinear;, score=0.797 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=500, penalty=l1, solver=liblinear;, score=0.783 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=500, penalty=l1, solver=liblinear;, score=0.808 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=500, penalty=l1, solver=liblinear;, score=0.798 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=500, penalty=l1, solver=liblinear;, score=0.800 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=500, penalty=l2, solver=newton-cg;, score=0.801 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=500, penalty=l2, solver=newton-cg;, score=0.797 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=500, penalty=l2, solver=newton-cg;, score=0.816 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=500, penalty=l2, solver=newton-cg;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=500, penalty=l2, solver=newton-cg;, score=0.820 total time=   0.0s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5] END C=0.001, max_iter=500, penalty=l2, solver=lbfgs;, score=0.801 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=500, penalty=l2, solver=lbfgs;, score=0.797 total time=   0.0s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5] END C=0.001, max_iter=500, penalty=l2, solver=lbfgs;, score=0.810 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=500, penalty=l2, solver=lbfgs;, score=0.814 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=500, penalty=l2, solver=lbfgs;, score=0.805 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=500, penalty=l2, solver=liblinear;, score=0.802 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=500, penalty=l2, solver=liblinear;, score=0.792 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=500, penalty=l2, solver=liblinear;, score=0.807 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=500, penalty=l2, solver=liblinear;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=500, penalty=l2, solver=liblinear;, score=0.803 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=600, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=600, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=600, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=600, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=600, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=600, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=600, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=600, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=600, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=600, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=600, penalty=l1, solver=liblinear;, score=0.797 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=600, penalty=l1, solver=liblinear;, score=0.783 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=600, penalty=l1, solver=liblinear;, score=0.808 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=600, penalty=l1, solver=liblinear;, score=0.798 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=600, penalty=l1, solver=liblinear;, score=0.800 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=600, penalty=l2, solver=newton-cg;, score=0.801 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=600, penalty=l2, solver=newton-cg;, score=0.797 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=600, penalty=l2, solver=newton-cg;, score=0.816 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=600, penalty=l2, solver=newton-cg;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=600, penalty=l2, solver=newton-cg;, score=0.820 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=600, penalty=l2, solver=lbfgs;, score=0.798 total time=   0.0s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END C=0.001, max_iter=600, penalty=l2, solver=lbfgs;, score=0.798 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=600, penalty=l2, solver=lbfgs;, score=0.816 total time=   0.0s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END C=0.001, max_iter=600, penalty=l2, solver=lbfgs;, score=0.813 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=600, penalty=l2, solver=lbfgs;, score=0.805 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=600, penalty=l2, solver=liblinear;, score=0.802 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=600, penalty=l2, solver=liblinear;, score=0.792 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=600, penalty=l2, solver=liblinear;, score=0.807 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=600, penalty=l2, solver=liblinear;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=600, penalty=l2, solver=liblinear;, score=0.803 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=700, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=700, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=700, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=700, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=700, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=700, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=700, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=700, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=700, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=700, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=700, penalty=l1, solver=liblinear;, score=0.797 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=700, penalty=l1, solver=liblinear;, score=0.783 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=700, penalty=l1, solver=liblinear;, score=0.808 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=700, penalty=l1, solver=liblinear;, score=0.798 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=700, penalty=l1, solver=liblinear;, score=0.800 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=700, penalty=l2, solver=newton-cg;, score=0.801 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=700, penalty=l2, solver=newton-cg;, score=0.797 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=700, penalty=l2, solver=newton-cg;, score=0.816 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=700, penalty=l2, solver=newton-cg;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=700, penalty=l2, solver=newton-cg;, score=0.820 total time=   0.0s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5] END C=0.001, max_iter=700, penalty=l2, solver=lbfgs;, score=0.801 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=700, penalty=l2, solver=lbfgs;, score=0.798 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=700, penalty=l2, solver=lbfgs;, score=0.818 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=700, penalty=l2, solver=lbfgs;, score=0.811 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=700, penalty=l2, solver=lbfgs;, score=0.805 total time=   0.0s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5] END C=0.001, max_iter=700, penalty=l2, solver=liblinear;, score=0.802 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=700, penalty=l2, solver=liblinear;, score=0.792 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=700, penalty=l2, solver=liblinear;, score=0.807 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=700, penalty=l2, solver=liblinear;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=700, penalty=l2, solver=liblinear;, score=0.803 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=800, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=800, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=800, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=800, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=800, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=800, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=800, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=800, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=800, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=800, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=800, penalty=l1, solver=liblinear;, score=0.797 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=800, penalty=l1, solver=liblinear;, score=0.783 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=800, penalty=l1, solver=liblinear;, score=0.808 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=800, penalty=l1, solver=liblinear;, score=0.798 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=800, penalty=l1, solver=liblinear;, score=0.800 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=800, penalty=l2, solver=newton-cg;, score=0.801 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=800, penalty=l2, solver=newton-cg;, score=0.797 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=800, penalty=l2, solver=newton-cg;, score=0.816 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=800, penalty=l2, solver=newton-cg;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=800, penalty=l2, solver=newton-cg;, score=0.820 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=800, penalty=l2, solver=lbfgs;, score=0.798 total time=   0.1s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END C=0.001, max_iter=800, penalty=l2, solver=lbfgs;, score=0.797 total time=   0.1s
# [CV 3/5] END C=0.001, max_iter=800, penalty=l2, solver=lbfgs;, score=0.818 total time=   0.1s
# [CV 4/5] END C=0.001, max_iter=800, penalty=l2, solver=lbfgs;, score=0.812 total time=   0.1s
# [CV 5/5] END C=0.001, max_iter=800, penalty=l2, solver=lbfgs;, score=0.805 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=800, penalty=l2, solver=liblinear;, score=0.802 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=800, penalty=l2, solver=liblinear;, score=0.792 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=800, penalty=l2, solver=liblinear;, score=0.807 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=800, penalty=l2, solver=liblinear;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=800, penalty=l2, solver=liblinear;, score=0.803 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=900, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=900, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=900, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=900, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=900, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=900, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=900, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=900, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=900, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=900, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=900, penalty=l1, solver=liblinear;, score=0.797 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=900, penalty=l1, solver=liblinear;, score=0.783 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=900, penalty=l1, solver=liblinear;, score=0.808 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=900, penalty=l1, solver=liblinear;, score=0.798 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=900, penalty=l1, solver=liblinear;, score=0.800 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=900, penalty=l2, solver=newton-cg;, score=0.801 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=900, penalty=l2, solver=newton-cg;, score=0.797 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=900, penalty=l2, solver=newton-cg;, score=0.816 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=900, penalty=l2, solver=newton-cg;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=900, penalty=l2, solver=newton-cg;, score=0.820 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=900, penalty=l2, solver=lbfgs;, score=0.798 total time=   0.1s
# [CV 2/5] END C=0.001, max_iter=900, penalty=l2, solver=lbfgs;, score=0.797 total time=   0.2s
# [CV 3/5] END C=0.001, max_iter=900, penalty=l2, solver=lbfgs;, score=0.818 total time=   0.1s
# [CV 4/5] END C=0.001, max_iter=900, penalty=l2, solver=lbfgs;, score=0.812 total time=   0.1s
# [CV 5/5] END C=0.001, max_iter=900, penalty=l2, solver=lbfgs;, score=0.805 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=900, penalty=l2, solver=liblinear;, score=0.802 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=900, penalty=l2, solver=liblinear;, score=0.792 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=900, penalty=l2, solver=liblinear;, score=0.807 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=900, penalty=l2, solver=liblinear;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=900, penalty=l2, solver=liblinear;, score=0.803 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l1, solver=liblinear;, score=0.797 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l1, solver=liblinear;, score=0.783 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l1, solver=liblinear;, score=0.808 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l1, solver=liblinear;, score=0.798 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l1, solver=liblinear;, score=0.800 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, solver=newton-cg;, score=0.801 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, solver=newton-cg;, score=0.797 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, solver=newton-cg;, score=0.816 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, solver=newton-cg;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, solver=newton-cg;, score=0.820 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, solver=lbfgs;, score=0.798 total time=   0.1s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, solver=lbfgs;, score=0.797 total time=   0.1s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, solver=lbfgs;, score=0.818 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, solver=lbfgs;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, solver=lbfgs;, score=0.805 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, solver=liblinear;, score=0.802 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, solver=liblinear;, score=0.792 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, solver=liblinear;, score=0.807 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, solver=liblinear;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, solver=liblinear;, score=0.803 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=1100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=1100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=1100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=1100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=1100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=1100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=1100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=1100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=1100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=1100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=1100, penalty=l1, solver=liblinear;, score=0.797 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=1100, penalty=l1, solver=liblinear;, score=0.783 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=1100, penalty=l1, solver=liblinear;, score=0.808 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=1100, penalty=l1, solver=liblinear;, score=0.798 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=1100, penalty=l1, solver=liblinear;, score=0.800 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=1100, penalty=l2, solver=newton-cg;, score=0.801 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=1100, penalty=l2, solver=newton-cg;, score=0.797 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=1100, penalty=l2, solver=newton-cg;, score=0.816 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=1100, penalty=l2, solver=newton-cg;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=1100, penalty=l2, solver=newton-cg;, score=0.820 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=1100, penalty=l2, solver=lbfgs;, score=0.798 total time=   0.1s
# [CV 2/5] END C=0.001, max_iter=1100, penalty=l2, solver=lbfgs;, score=0.797 total time=   0.1s
# [CV 3/5] END C=0.001, max_iter=1100, penalty=l2, solver=lbfgs;, score=0.818 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=1100, penalty=l2, solver=lbfgs;, score=0.812 total time=   0.1s
# [CV 5/5] END C=0.001, max_iter=1100, penalty=l2, solver=lbfgs;, score=0.805 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=1100, penalty=l2, solver=liblinear;, score=0.802 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=1100, penalty=l2, solver=liblinear;, score=0.792 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=1100, penalty=l2, solver=liblinear;, score=0.807 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=1100, penalty=l2, solver=liblinear;, score=0.812 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=1100, penalty=l2, solver=liblinear;, score=0.803 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=1200, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=1200, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=1200, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=1200, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=1200, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=1200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=1200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=1200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=1200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=1200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=1200, penalty=l1, solver=liblinear;, score=0.797 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=1200, penalty=l1, solver=liblinear;, score=0.783 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=1200, penalty=l1, solver=liblinear;, score=0.808 total time=   0.0s
# ...
# [CV 3/5] END C=0.1, max_iter=2900, penalty=l2, solver=liblinear;, score=0.814 total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=2900, penalty=l2, solver=liblinear;, score=0.819 total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=2900, penalty=l2, solver=liblinear;, score=0.819 total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3000, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3000, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3000, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3000, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3000, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3000, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3000, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3000, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3000, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3000, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3000, penalty=l1, solver=liblinear;, score=0.803 total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3000, penalty=l1, solver=liblinear;, score=0.803 total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3000, penalty=l1, solver=liblinear;, score=0.817 total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3000, penalty=l1, solver=liblinear;, score=0.821 total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3000, penalty=l1, solver=liblinear;, score=0.817 total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3000, penalty=l2, solver=newton-cg;, score=0.803 total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3000, penalty=l2, solver=newton-cg;, score=0.798 total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3000, penalty=l2, solver=newton-cg;, score=0.819 total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3000, penalty=l2, solver=newton-cg;, score=0.817 total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3000, penalty=l2, solver=newton-cg;, score=0.815 total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3000, penalty=l2, solver=lbfgs;, score=0.803 total time=   0.2s
# [CV 2/5] END C=0.1, max_iter=3000, penalty=l2, solver=lbfgs;, score=0.800 total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3000, penalty=l2, solver=lbfgs;, score=0.817 total time=   0.3s
# [CV 4/5] END C=0.1, max_iter=3000, penalty=l2, solver=lbfgs;, score=0.819 total time=   0.2s
# [CV 5/5] END C=0.1, max_iter=3000, penalty=l2, solver=lbfgs;, score=0.816 total time=   0.3s
# [CV 1/5] END C=0.1, max_iter=3000, penalty=l2, solver=liblinear;, score=0.809 total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3000, penalty=l2, solver=liblinear;, score=0.807 total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3000, penalty=l2, solver=liblinear;, score=0.814 total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3000, penalty=l2, solver=liblinear;, score=0.819 total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3000, penalty=l2, solver=liblinear;, score=0.819 total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3100, penalty=l1, solver=liblinear;, score=0.803 total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3100, penalty=l1, solver=liblinear;, score=0.803 total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3100, penalty=l1, solver=liblinear;, score=0.818 total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3100, penalty=l1, solver=liblinear;, score=0.821 total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3100, penalty=l1, solver=liblinear;, score=0.817 total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3100, penalty=l2, solver=newton-cg;, score=0.803 total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3100, penalty=l2, solver=newton-cg;, score=0.798 total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3100, penalty=l2, solver=newton-cg;, score=0.819 total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3100, penalty=l2, solver=newton-cg;, score=0.817 total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3100, penalty=l2, solver=newton-cg;, score=0.815 total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3100, penalty=l2, solver=lbfgs;, score=0.803 total time=   0.2s
# [CV 2/5] END C=0.1, max_iter=3100, penalty=l2, solver=lbfgs;, score=0.800 total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3100, penalty=l2, solver=lbfgs;, score=0.817 total time=   0.2s
# [CV 4/5] END C=0.1, max_iter=3100, penalty=l2, solver=lbfgs;, score=0.819 total time=   0.2s
# [CV 5/5] END C=0.1, max_iter=3100, penalty=l2, solver=lbfgs;, score=0.816 total time=   0.2s
# [CV 1/5] END C=0.1, max_iter=3100, penalty=l2, solver=liblinear;, score=0.809 total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3100, penalty=l2, solver=liblinear;, score=0.807 total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3100, penalty=l2, solver=liblinear;, score=0.814 total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3100, penalty=l2, solver=liblinear;, score=0.819 total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3100, penalty=l2, solver=liblinear;, score=0.819 total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3200, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3200, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3200, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3200, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3200, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3200, penalty=l1, solver=liblinear;, score=0.803 total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3200, penalty=l1, solver=liblinear;, score=0.803 total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3200, penalty=l1, solver=liblinear;, score=0.817 total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3200, penalty=l1, solver=liblinear;, score=0.821 total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3200, penalty=l1, solver=liblinear;, score=0.817 total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3200, penalty=l2, solver=newton-cg;, score=0.803 total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3200, penalty=l2, solver=newton-cg;, score=0.798 total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3200, penalty=l2, solver=newton-cg;, score=0.819 total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3200, penalty=l2, solver=newton-cg;, score=0.817 total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3200, penalty=l2, solver=newton-cg;, score=0.815 total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3200, penalty=l2, solver=lbfgs;, score=0.803 total time=   0.3s
# [CV 2/5] END C=0.1, max_iter=3200, penalty=l2, solver=lbfgs;, score=0.800 total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3200, penalty=l2, solver=lbfgs;, score=0.817 total time=   0.3s
# [CV 4/5] END C=0.1, max_iter=3200, penalty=l2, solver=lbfgs;, score=0.819 total time=   0.3s
# [CV 5/5] END C=0.1, max_iter=3200, penalty=l2, solver=lbfgs;, score=0.816 total time=   0.3s
# [CV 1/5] END C=0.1, max_iter=3200, penalty=l2, solver=liblinear;, score=0.809 total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3200, penalty=l2, solver=liblinear;, score=0.807 total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3200, penalty=l2, solver=liblinear;, score=0.814 total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3200, penalty=l2, solver=liblinear;, score=0.819 total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3200, penalty=l2, solver=liblinear;, score=0.819 total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3300, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3300, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3300, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3300, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3300, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3300, penalty=l1, solver=liblinear;, score=0.803 total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3300, penalty=l1, solver=liblinear;, score=0.803 total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3300, penalty=l1, solver=liblinear;, score=0.817 total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3300, penalty=l1, solver=liblinear;, score=0.821 total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3300, penalty=l1, solver=liblinear;, score=0.817 total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3300, penalty=l2, solver=newton-cg;, score=0.803 total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3300, penalty=l2, solver=newton-cg;, score=0.798 total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3300, penalty=l2, solver=newton-cg;, score=0.819 total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3300, penalty=l2, solver=newton-cg;, score=0.817 total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3300, penalty=l2, solver=newton-cg;, score=0.815 total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3300, penalty=l2, solver=lbfgs;, score=0.803 total time=   0.3s
# [CV 2/5] END C=0.1, max_iter=3300, penalty=l2, solver=lbfgs;, score=0.800 total time=   0.1s
# [CV 3/5] END C=0.1, max_iter=3300, penalty=l2, solver=lbfgs;, score=0.817 total time=   0.4s
# [CV 4/5] END C=0.1, max_iter=3300, penalty=l2, solver=lbfgs;, score=0.819 total time=   0.2s
# [CV 5/5] END C=0.1, max_iter=3300, penalty=l2, solver=lbfgs;, score=0.816 total time=   0.3s
# [CV 1/5] END C=0.1, max_iter=3300, penalty=l2, solver=liblinear;, score=0.809 total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3300, penalty=l2, solver=liblinear;, score=0.807 total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3300, penalty=l2, solver=liblinear;, score=0.814 total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3300, penalty=l2, solver=liblinear;, score=0.819 total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3300, penalty=l2, solver=liblinear;, score=0.819 total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3400, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3400, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3400, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3400, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3400, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3400, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3400, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3400, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3400, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3400, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3400, penalty=l1, solver=liblinear;, score=0.803 total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3400, penalty=l1, solver=liblinear;, score=0.803 total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3400, penalty=l1, solver=liblinear;, score=0.818 total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3400, penalty=l1, solver=liblinear;, score=0.821 total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3400, penalty=l1, solver=liblinear;, score=0.817 total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3400, penalty=l2, solver=newton-cg;, score=0.803 total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3400, penalty=l2, solver=newton-cg;, score=0.798 total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3400, penalty=l2, solver=newton-cg;, score=0.819 total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3400, penalty=l2, solver=newton-cg;, score=0.817 total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3400, penalty=l2, solver=newton-cg;, score=0.815 total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3400, penalty=l2, solver=lbfgs;, score=0.803 total time=   0.2s
# [CV 2/5] END C=0.1, max_iter=3400, penalty=l2, solver=lbfgs;, score=0.800 total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3400, penalty=l2, solver=lbfgs;, score=0.817 total time=   0.3s
# [CV 4/5] END C=0.1, max_iter=3400, penalty=l2, solver=lbfgs;, score=0.819 total time=   0.2s
# [CV 5/5] END C=0.1, max_iter=3400, penalty=l2, solver=lbfgs;, score=0.816 total time=   0.3s
# [CV 1/5] END C=0.1, max_iter=3400, penalty=l2, solver=liblinear;, score=0.809 total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3400, penalty=l2, solver=liblinear;, score=0.807 total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3400, penalty=l2, solver=liblinear;, score=0.814 total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3400, penalty=l2, solver=liblinear;, score=0.819 total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3400, penalty=l2, solver=liblinear;, score=0.819 total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3500, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3500, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3500, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3500, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3500, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3500, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3500, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3500, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3500, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3500, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=3500, penalty=l1, solver=liblinear;, score=0.803 total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=3500, penalty=l1, solver=liblinear;, score=0.803 total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=3500, penalty=l1, solver=liblinear;, score=0.818 total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=3500, penalty=l1, solver=liblinear;, score=0.821 total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=3500, penalty=l1, solver=liblinear;, score=0.817 total time=   0.0s

# %%
LR_search.best_params_
# summarize
print('Best F1 score Accuracy: %.3f' % LR_search.best_score_)
print('Config: %s' % LR_search.best_params_)

# %%
from sklearn.model_selection import KFold 
k = 5
kf = KFold(n_splits=k, random_state=None)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
result = cross_val_score(LR_search , x, y, cv = kf)
 
print("Avg accuracy: {}".format(result.mean()))
# Out:
# Fitting 5 folds for each of 490 candidates, totalling 2450 fits
# [CV 1/5] END C=0.001, max_iter=100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END C=0.001, max_iter=100, penalty=l1, solver=liblinear;, score=0.702 total time=   0.1s
# [CV 2/5] END C=0.001, max_iter=100, penalty=l1, solver=liblinear;, score=0.629 total time=   0.2s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END C=0.001, max_iter=100, penalty=l1, solver=liblinear;, score=0.626 total time=   0.1s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END C=0.001, max_iter=100, penalty=l1, solver=liblinear;, score=0.596 total time=   0.1s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END C=0.001, max_iter=100, penalty=l1, solver=liblinear;, score=0.593 total time=   0.1s
# [CV 1/5] END C=0.001, max_iter=100, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=100, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=100, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=100, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=100, penalty=l1, solver=sag;, score=nan total time=   0.0s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END C=0.001, max_iter=100, penalty=l1, solver=saga;, score=0.478 total time=   2.1s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END C=0.001, max_iter=100, penalty=l1, solver=saga;, score=0.476 total time=   2.1s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END C=0.001, max_iter=100, penalty=l1, solver=saga;, score=0.477 total time=   2.0s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END C=0.001, max_iter=100, penalty=l1, solver=saga;, score=0.479 total time=   2.1s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END C=0.001, max_iter=100, penalty=l1, solver=saga;, score=0.477 total time=   1.9s
# C:\Users\agnes\anaconda3\lib\site-packages\scipy\optimize\linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# C:\Users\agnes\anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\optimize.py:204: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg;, score=0.705 total time=   2.7s
# [CV 2/5] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg;, score=0.675 total time=   2.4s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg;, score=0.627 total time=   2.4s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg;, score=0.595 total time=   2.7s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END C=0.001, max_iter=100, penalty=l2, solver=newton-cg;, score=0.580 total time=   2.6s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs;, score=0.687 total time=   0.4s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs;, score=0.641 total time=   0.4s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs;, score=0.622 total time=   0.4s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs;, score=0.608 total time=   0.4s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END C=0.001, max_iter=100, penalty=l2, solver=lbfgs;, score=0.563 total time=   0.4s
# [CV 1/5] END C=0.001, max_iter=100, penalty=l2, solver=liblinear;, score=0.696 total time=   0.3s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END C=0.001, max_iter=100, penalty=l2, solver=liblinear;, score=0.651 total time=   0.3s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END C=0.001, max_iter=100, penalty=l2, solver=liblinear;, score=0.624 total time=   0.4s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END C=0.001, max_iter=100, penalty=l2, solver=liblinear;, score=0.600 total time=   0.3s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END C=0.001, max_iter=100, penalty=l2, solver=liblinear;, score=0.562 total time=   0.3s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END C=0.001, max_iter=100, penalty=l2, solver=sag;, score=0.478 total time=   1.5s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END C=0.001, max_iter=100, penalty=l2, solver=sag;, score=0.478 total time=   1.5s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END C=0.001, max_iter=100, penalty=l2, solver=sag;, score=0.478 total time=   1.4s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END C=0.001, max_iter=100, penalty=l2, solver=sag;, score=0.480 total time=   1.4s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END C=0.001, max_iter=100, penalty=l2, solver=sag;, score=0.478 total time=   1.4s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END C=0.001, max_iter=100, penalty=l2, solver=saga;, score=0.478 total time=   1.6s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END C=0.001, max_iter=100, penalty=l2, solver=saga;, score=0.477 total time=   1.6s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END C=0.001, max_iter=100, penalty=l2, solver=saga;, score=0.477 total time=   1.6s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END C=0.001, max_iter=100, penalty=l2, solver=saga;, score=0.479 total time=   1.6s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END C=0.001, max_iter=100, penalty=l2, solver=saga;, score=0.477 total time=   1.6s
# [CV 1/5] END C=0.001, max_iter=200, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=200, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=200, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=200, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=200, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=200, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=200, penalty=l1, solver=liblinear;, score=0.702 total time=   0.1s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END C=0.001, max_iter=200, penalty=l1, solver=liblinear;, score=0.629 total time=   0.1s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END C=0.001, max_iter=200, penalty=l1, solver=liblinear;, score=0.625 total time=   0.1s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END C=0.001, max_iter=200, penalty=l1, solver=liblinear;, score=0.596 total time=   0.1s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END C=0.001, max_iter=200, penalty=l1, solver=liblinear;, score=0.593 total time=   0.1s
# [CV 1/5] END C=0.001, max_iter=200, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=200, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=200, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=200, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=200, penalty=l1, solver=sag;, score=nan total time=   0.0s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END C=0.001, max_iter=200, penalty=l1, solver=saga;, score=0.478 total time=   3.8s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END C=0.001, max_iter=200, penalty=l1, solver=saga;, score=0.478 total time=   3.8s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END C=0.001, max_iter=200, penalty=l1, solver=saga;, score=0.478 total time=   3.8s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END C=0.001, max_iter=200, penalty=l1, solver=saga;, score=0.480 total time=   3.8s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END C=0.001, max_iter=200, penalty=l1, solver=saga;, score=0.478 total time=   3.8s
# C:\Users\agnes\anaconda3\lib\site-packages\scipy\optimize\linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# C:\Users\agnes\anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\optimize.py:204: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg;, score=0.705 total time=   2.6s
# [CV 2/5] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg;, score=0.675 total time=   2.4s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg;, score=0.627 total time=   2.4s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg;, score=0.595 total time=   2.8s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END C=0.001, max_iter=200, penalty=l2, solver=newton-cg;, score=0.580 total time=   2.7s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs;, score=0.697 total time=   0.6s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs;, score=0.654 total time=   0.9s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs;, score=0.623 total time=   0.9s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs;, score=0.597 total time=   0.9s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END C=0.001, max_iter=200, penalty=l2, solver=lbfgs;, score=0.566 total time=   0.9s
# [CV 1/5] END C=0.001, max_iter=200, penalty=l2, solver=liblinear;, score=0.696 total time=   0.3s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END C=0.001, max_iter=200, penalty=l2, solver=liblinear;, score=0.651 total time=   0.3s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END C=0.001, max_iter=200, penalty=l2, solver=liblinear;, score=0.624 total time=   0.4s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END C=0.001, max_iter=200, penalty=l2, solver=liblinear;, score=0.600 total time=   0.4s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END C=0.001, max_iter=200, penalty=l2, solver=liblinear;, score=0.562 total time=   0.3s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END C=0.001, max_iter=200, penalty=l2, solver=sag;, score=0.478 total time=   3.0s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END C=0.001, max_iter=200, penalty=l2, solver=sag;, score=0.478 total time=   2.9s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END C=0.001, max_iter=200, penalty=l2, solver=sag;, score=0.478 total time=   3.0s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END C=0.001, max_iter=200, penalty=l2, solver=sag;, score=0.480 total time=   2.9s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END C=0.001, max_iter=200, penalty=l2, solver=sag;, score=0.478 total time=   2.9s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END C=0.001, max_iter=200, penalty=l2, solver=saga;, score=0.478 total time=   3.2s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END C=0.001, max_iter=200, penalty=l2, solver=saga;, score=0.478 total time=   3.3s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END C=0.001, max_iter=200, penalty=l2, solver=saga;, score=0.478 total time=   3.2s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END C=0.001, max_iter=200, penalty=l2, solver=saga;, score=0.480 total time=   3.4s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END C=0.001, max_iter=200, penalty=l2, solver=saga;, score=0.478 total time=   3.3s
# [CV 1/5] END C=0.001, max_iter=300, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=300, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=300, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=300, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=300, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=300, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=300, penalty=l1, solver=liblinear;, score=0.702 total time=   0.1s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END C=0.001, max_iter=300, penalty=l1, solver=liblinear;, score=0.629 total time=   0.1s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END C=0.001, max_iter=300, penalty=l1, solver=liblinear;, score=0.625 total time=   0.1s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END C=0.001, max_iter=300, penalty=l1, solver=liblinear;, score=0.596 total time=   0.1s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END C=0.001, max_iter=300, penalty=l1, solver=liblinear;, score=0.593 total time=   0.2s
# [CV 1/5] END C=0.001, max_iter=300, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=300, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=300, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=300, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=300, penalty=l1, solver=sag;, score=nan total time=   0.0s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END C=0.001, max_iter=300, penalty=l1, solver=saga;, score=0.478 total time=   5.7s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END C=0.001, max_iter=300, penalty=l1, solver=saga;, score=0.478 total time=   5.7s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END C=0.001, max_iter=300, penalty=l1, solver=saga;, score=0.478 total time=   5.9s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END C=0.001, max_iter=300, penalty=l1, solver=saga;, score=0.480 total time=   5.7s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END C=0.001, max_iter=300, penalty=l1, solver=saga;, score=0.478 total time=   5.8s
# C:\Users\agnes\anaconda3\lib\site-packages\scipy\optimize\linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# C:\Users\agnes\anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\optimize.py:204: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg;, score=0.705 total time=   2.6s
# [CV 2/5] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg;, score=0.675 total time=   2.4s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg;, score=0.627 total time=   2.4s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg;, score=0.595 total time=   2.7s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END C=0.001, max_iter=300, penalty=l2, solver=newton-cg;, score=0.580 total time=   2.5s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END C=0.001, max_iter=300, penalty=l2, solver=lbfgs;, score=0.697 total time=   0.6s
# ...
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END C=0.01, max_iter=600, penalty=l2, solver=sag;, score=0.492 total time=   8.7s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END C=0.01, max_iter=600, penalty=l2, solver=sag;, score=0.485 total time=   8.7s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END C=0.01, max_iter=600, penalty=l2, solver=sag;, score=0.490 total time=   8.8s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END C=0.01, max_iter=600, penalty=l2, solver=saga;, score=0.478 total time=  10.0s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END C=0.01, max_iter=600, penalty=l2, solver=saga;, score=0.478 total time=   9.7s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END C=0.01, max_iter=600, penalty=l2, solver=saga;, score=0.478 total time=   9.7s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END C=0.01, max_iter=600, penalty=l2, solver=saga;, score=0.478 total time=   9.9s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END C=0.01, max_iter=600, penalty=l2, solver=saga;, score=0.478 total time=   9.8s
# [CV 1/5] END C=0.01, max_iter=700, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=700, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=700, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=700, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=700, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=0.01, max_iter=700, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=700, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=700, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=700, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=700, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.01, max_iter=700, penalty=l1, solver=liblinear;, score=0.703 total time=   0.1s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END C=0.01, max_iter=700, penalty=l1, solver=liblinear;, score=0.656 total time=   0.4s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END C=0.01, max_iter=700, penalty=l1, solver=liblinear;, score=0.628 total time=   0.3s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END C=0.01, max_iter=700, penalty=l1, solver=liblinear;, score=0.600 total time=   0.5s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END C=0.01, max_iter=700, penalty=l1, solver=liblinear;, score=0.566 total time=   0.3s
# [CV 1/5] END C=0.01, max_iter=700, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=700, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=700, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=700, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=700, penalty=l1, solver=sag;, score=nan total time=   0.0s
# C:\Users\agnes\anaconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7752/790826492.py in <module>
#       1 from sklearn.model_selection import cross_val_score
#       2 from sklearn.model_selection import KFold
# ----> 3 result = cross_val_score(LR_search , x, y, cv = kf)
#       4
#       5 print("Avg accuracy: {}".format(result.mean()))
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     560     scorer = check_scoring(estimator, scoring=scoring)
#     561
# --> 562     cv_results = cross_validate(
#     563         estimator=estimator,
#     564         X=X,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py in wrapper(*args, **kwargs)
#     212                     )
#     213                 ):
# --> 214                     return func(*args, **kwargs)
#     215             except InvalidParameterError as e:
#     216                 # When the function is just a wrapper around an estimator, we allow
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     307     # independent, and that it is pickle-able.
#     308     parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 309     results = parallel(
#     310         delayed(_fit_and_score)(
#     311             clone(estimator),
#
# ~\anaconda3\lib\site-packages\sklearn\utils\parallel.py in __call__(self, iterable)
#      63             for delayed_func, args, kwargs in iterable
#      64         )
# ---> 65         return super().__call__(iterable_with_config)
#      66
#      67
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1861             output = self._get_sequential_output(iterable)
#    1862             next(output)
# -> 1863             return output if self.return_generator else list(output)
#    1864
#    1865         # Let's create an ID that uniquely identifies the current call. If the
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _get_sequential_output(self, iterable)
#    1790                 self.n_dispatched_batches += 1
#    1791                 self.n_dispatched_tasks += 1
# -> 1792                 res = func(*args, **kwargs)
#    1793                 self.n_completed_tasks += 1
#    1794                 self.print_progress()
#
# ~\anaconda3\lib\site-packages\sklearn\utils\parallel.py in __call__(self, *args, **kwargs)
#     125             config = {}
#     126         with config_context(**config):
# --> 127             return self.function(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     727             estimator.fit(X_train, **fit_params)
#     728         else:
# --> 729             estimator.fit(X_train, y_train, **fit_params)
#     730
#     731     except Exception:
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     896                 return results
#     897
# --> 898             self._run_search(evaluate_candidates)
#     899
#     900             # multimetric is determined here because in the case of a callable
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1420     def _run_search(self, evaluate_candidates):
#    1421         """Search all candidates in param_grid"""
# -> 1422         evaluate_candidates(ParameterGrid(self.param_grid))
#    1423
#    1424
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     843                     )
#     844
# --> 845                 out = parallel(
#     846                     delayed(_fit_and_score)(
#     847                         clone(base_estimator),
#
# ~\anaconda3\lib\site-packages\sklearn\utils\parallel.py in __call__(self, iterable)
#      63             for delayed_func, args, kwargs in iterable
#      64         )
# ---> 65         return super().__call__(iterable_with_config)
#      66
#      67
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1861             output = self._get_sequential_output(iterable)
#    1862             next(output)
# -> 1863             return output if self.return_generator else list(output)
#    1864
#    1865         # Let's create an ID that uniquely identifies the current call. If the
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _get_sequential_output(self, iterable)
#    1790                 self.n_dispatched_batches += 1
#    1791                 self.n_dispatched_tasks += 1
# -> 1792                 res = func(*args, **kwargs)
#    1793                 self.n_completed_tasks += 1
#    1794                 self.print_progress()
#
# ~\anaconda3\lib\site-packages\sklearn\utils\parallel.py in __call__(self, *args, **kwargs)
#     125             config = {}
#     126         with config_context(**config):
# --> 127             return self.function(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     727             estimator.fit(X_train, **fit_params)
#     728         else:
# --> 729             estimator.fit(X_train, y_train, **fit_params)
#     730
#     731     except Exception:
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1301             n_threads = 1
#    1302
# -> 1303         fold_coefs_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose, prefer=prefer)(
#    1304             path_func(
#    1305                 X,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\parallel.py in __call__(self, iterable)
#      63             for delayed_func, args, kwargs in iterable
#      64         )
# ---> 65         return super().__call__(iterable_with_config)
#      66
#      67
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1861             output = self._get_sequential_output(iterable)
#    1862             next(output)
# -> 1863             return output if self.return_generator else list(output)
#    1864
#    1865         # Let's create an ID that uniquely identifies the current call. If the
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _get_sequential_output(self, iterable)
#    1790                 self.n_dispatched_batches += 1
#    1791                 self.n_dispatched_tasks += 1
# -> 1792                 res = func(*args, **kwargs)
#    1793                 self.n_completed_tasks += 1
#    1794                 self.print_progress()
#
# ~\anaconda3\lib\site-packages\sklearn\utils\parallel.py in __call__(self, *args, **kwargs)
#     125             config = {}
#     126         with config_context(**config):
# --> 127             return self.function(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio, n_threads)
#     531                 beta = (1.0 / C) * l1_ratio
#     532
# --> 533             w0, n_iter_i, warm_start_sag = sag_solver(
#     534                 X,
#     535                 target,
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py in sag_solver(X, y, sample_weight, loss, alpha, beta, max_iter, tol, verbose, random_state, check_input, max_squared_sum, warm_start_mem, is_saga)
#     323
#     324     sag = sag64 if X.dtype == np.float64 else sag32
# --> 325     num_seen, n_iter_ = sag(
#     326         dataset,
#     327         coef_init,
#
# KeyboardInterrupt:
