# %%
pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Using cached sentence_transformers-2.2.2-py3-none-any.whl
# Requirement already satisfied: torch>=1.6.0 in c:\users\agnes\anaconda3\lib\site-packages (from sentence_transformers) (2.1.2)
# Requirement already satisfied: tqdm in c:\users\agnes\anaconda3\lib\site-packages (from sentence_transformers) (4.62.3)
# Collecting sentencepiece
#   Using cached sentencepiece-0.1.99-cp39-cp39-win_amd64.whl (977 kB)
# Requirement already satisfied: scikit-learn in c:\users\agnes\anaconda3\lib\site-packages (from sentence_transformers) (1.3.2)
# Requirement already satisfied: huggingface-hub>=0.4.0 in c:\users\agnes\anaconda3\lib\site-packages (from sentence_transformers) (0.20.1)
# Collecting torchvision
#   Using cached torchvision-0.16.2-cp39-cp39-win_amd64.whl (1.1 MB)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in c:\users\agnes\anaconda3\lib\site-packages (from sentence_transformers) (4.36.2)
# Requirement already satisfied: nltk in c:\users\agnes\anaconda3\lib\site-packages (from sentence_transformers) (3.6.5)
# Requirement already satisfied: scipy in c:\users\agnes\anaconda3\lib\site-packages (from sentence_transformers) (1.7.1)
# Requirement already satisfied: numpy in c:\users\agnes\anaconda3\lib\site-packages (from sentence_transformers) (1.22.4)
# Requirement already satisfied: filelock in c:\users\agnes\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.3.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\agnes\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\agnes\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\agnes\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (21.0)
# Requirement already satisfied: requests in c:\users\agnes\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.27.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\agnes\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.12.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\agnes\anaconda3\lib\site-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence_transformers) (3.0.4)
# Requirement already satisfied: networkx in c:\users\agnes\anaconda3\lib\site-packages (from torch>=1.6.0->sentence_transformers) (2.6.3)
# Requirement already satisfied: sympy in c:\users\agnes\anaconda3\lib\site-packages (from torch>=1.6.0->sentence_transformers) (1.9)
# Requirement already satisfied: jinja2 in c:\users\agnes\anaconda3\lib\site-packages (from torch>=1.6.0->sentence_transformers) (2.11.3)
# Requirement already satisfied: colorama in c:\users\agnes\anaconda3\lib\site-packages (from tqdm->sentence_transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\agnes\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\agnes\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.4.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\agnes\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2021.8.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\agnes\anaconda3\lib\site-packages (from jinja2->torch>=1.6.0->sentence_transformers) (1.1.1)
# Requirement already satisfied: click in c:\users\agnes\anaconda3\lib\site-packages (from nltk->sentence_transformers) (8.0.3)
# Requirement already satisfied: joblib in c:\users\agnes\anaconda3\lib\site-packages (from nltk->sentence_transformers) (1.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\agnes\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2021.10.8)Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agnes\anaconda3\lib\site-packages)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\agnes\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\agnes\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\agnes\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\agnes\anaconda3\lib\site-packages (from scikit-learn->sentence_transformers) (2.2.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\agnes\anaconda3\lib\site-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.2.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\agnes\anaconda3\lib\site-packages (from torchvision->sentence_transformers) (8.4.0)
# Installing collected packages: torchvision, sentencepiece, sentence-transformers
# Successfully installed sentence-transformers-2.2.2 sentencepiece-0.1.99 torchvision-0.16.2

# %%
pip install lightgbm
# Out:
# Collecting lightgbm
#   Downloading lightgbm-4.2.0-py3-none-win_amd64.whl (1.3 MB)
# Requirement already satisfied: numpy in c:\users\agnes\anaconda3\lib\site-packages (from lightgbm) (1.22.4)
# Requirement already satisfied: scipy in c:\users\agnes\anaconda3\lib\site-packages (from lightgbm) (1.7.1)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-4.2.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agnes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agnes\anaconda3\lib\site-packages)

# %%
## import statements 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.impute import SimpleImputer
# from sklearn.decomposition import PCA
from transformers import BertTokenizer, BertModel, AutoTokenizer, AutoModel
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report
# import tensorflow as tf
# from tensorflow.keras.preprocessing.text import Tokenizer
# from tensorflow.keras.preprocessing.sequence import pad_sequences
import gensim
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess
from gensim.models.phrases import Phrases, Phraser
from sentence_transformers import SentenceTransformer
from sklearn.linear_model import LinearRegression
from sklearn.metrics.pairwise import cosine_similarity
import lightgbm as lgb

# %%
# open data 
data= pd.read_csv("C:\\Users\\agnes\\Documents\\apziva_ai_residency\\project3\\data\\potential-talents.csv")
X = data.iloc[:, :-1]
X['embedding_Score'] = 0
X['similarity_BERT']=0

# %%
# BERT
model = SentenceTransformer('bert-base-nli-mean-tokens')

# Encode the sentences
embeddings = model.encode(X['job_title']).tolist()
embeding_score = []

for e in range(0, len(embeddings)-1):
    embeding_score.append(embeddings)
    X['embedding_Score'] = embeding_score[e]

# %%
print(X['embedding_Score'])
embeding_score = []

for e in range(0, len(embeddings)-1):
    embeding_score.append(embeddings)
    X['embedding_Score'] = embeding_score[e]

print(X['embedding_Score'])
# Out:
# 0      [-0.8347959518432617, 0.706193208694458, 1.411...
# 1      [-1.104152798652649, 0.6818206906318665, 0.480...
# 2      [0.46927979588508606, 0.2829471230506897, 2.33...
# 3      [-0.6027140021324158, -0.19602349400520325, 1....
# 4      [-0.05547751113772392, -0.19447185099124908, 1...
#                              ...
# 99     [-0.5095089077949524, 0.2794758677482605, 1.60...
# 100    [0.27189901471138, 0.06204644590616226, 1.3200...
# 101    [-0.5368146896362305, 0.6071465015411377, 1.69...
# 102    [0.12111370265483856, -0.07037004083395004, 2....
# 103    [-0.9533590078353882, 0.9029403328895569, 1.01...
# Name: embedding_Score, Length: 104, dtype: object
# 0      [-0.8347959518432617, 0.706193208694458, 1.411...
# 1      [-1.104152798652649, 0.6818206906318665, 0.480...
# 2      [0.46927979588508606, 0.2829471230506897, 2.33...
# 3      [-0.6027140021324158, -0.19602349400520325, 1....
# 4      [-0.05547751113772392, -0.19447185099124908, 1...
#                              ...
# 99     [-0.5095089077949524, 0.2794758677482605, 1.60...
# 100    [0.27189901471138, 0.06204644590616226, 1.3200...
# 101    [-0.5368146896362305, 0.6071465015411377, 1.69...
# 102    [0.12111370265483856, -0.07037004083395004, 2....
# 103    [-0.9533590078353882, 0.9029403328895569, 1.01...
# Name: embedding_Score, Length: 104, dtype: object

# %%
X['sentence1'] = "aspiring human resources"
X['sentence2'] = "seeking human resources"
embeddings1 = model.encode(X['sentence1']).tolist()
embeddings2 = model.encode(X['sentence2']).tolist()
# print(len(embeddings1))

# %%
embeding_score1 = []
embeding_score2 = []

for j in range(0, len(X['sentence1'])-1):
    embeding_score1.append(embeddings1)
    X['embedding_Score1'] = embeding_score1[j]

for em in range(0, len(X['sentence2'])-1):
    embeding_score2.append(embeddings2)
    X['embedding_Score2'] = embeding_score2[em]


print(X)
# Out:
#       id                                          job_title  \
# 0      1  2019 C.T. Bauer College of Business Graduate (...
# 1      2  Native English Teacher at EPIK (English Progra...
# 2      3              Aspiring Human Resources Professional
# 3      4             People Development Coordinator at Ryan
# 4      5    Advisory Board Member at Celal Bayar University
# ..   ...                                                ...
# 99   100  Aspiring Human Resources Manager | Graduating ...
# 100  101              Human Resources Generalist at Loparex
# 101  102   Business Intelligence and Analytics at Travelers
# 102  103                     Always set them up for Success
# 103  104   Director Of Administration at Excellence Logging
#
#                                 location connection  \
# 0                         Houston, Texas         85
# 1                                 Kanada      500+
# 2    Raleigh-Durham, North Carolina Area         44
# 3                          Denton, Texas      500+
# 4                         İzmir, Türkiye      500+
# ..                                   ...        ...
# 99              Cape Girardeau, Missouri        103
# 100  Raleigh-Durham, North Carolina Area      500+
# 101           Greater New York City Area         49
# 102             Greater Los Angeles Area      500+
# 103                          Katy, Texas      500+
#
#                                        embedding_Score  similarity_BERT  \
# 0    [-0.8347959518432617, 0.706193208694458, 1.411...                0
# 1    [-1.104152798652649, 0.6818206906318665, 0.480...                0
# 2    [0.46927979588508606, 0.2829471230506897, 2.33...                0
# 3    [-0.6027140021324158, -0.19602349400520325, 1....                0
# 4    [-0.05547751113772392, -0.19447185099124908, 1...                0
# ..                                                 ...              ...
# 99   [-0.5095089077949524, 0.2794758677482605, 1.60...                0
# 100  [0.27189901471138, 0.06204644590616226, 1.3200...                0
# 101  [-0.5368146896362305, 0.6071465015411377, 1.69...                0
# 102  [0.12111370265483856, -0.07037004083395004, 2....                0
# 103  [-0.9533590078353882, 0.9029403328895569, 1.01...                0
#
#                     sentence1                sentence2  \
# 0    aspiring human resources  seeking human resources
# 1    aspiring human resources  seeking human resources
# 2    aspiring human resources  seeking human resources
# 3    aspiring human resources  seeking human resources
# 4    aspiring human resources  seeking human resources
# ..                        ...                      ...
# 99   aspiring human resources  seeking human resources
# 100  aspiring human resources  seeking human resources
# 101  aspiring human resources  seeking human resources
# 102  aspiring human resources  seeking human resources
# 103  aspiring human resources  seeking human resources
#
#                                       embedding_Score1  \
# 0    [0.4868342876434326, -0.05931694433093071, 2.5...
# 1    [0.4868342876434326, -0.05931694433093071, 2.5...
# 2    [0.4868342876434326, -0.05931694433093071, 2.5...
# 3    [0.4868342876434326, -0.05931694433093071, 2.5...
# 4    [0.4868342876434326, -0.05931694433093071, 2.5...
# ..                                                 ...
# 99   [0.4868342876434326, -0.05931694433093071, 2.5...
# 100  [0.4868342876434326, -0.05931694433093071, 2.5...
# 101  [0.4868342876434326, -0.05931694433093071, 2.5...
# 102  [0.4868338108062744, -0.059316594153642654, 2....
# 103  [0.4868338108062744, -0.059316594153642654, 2....
#
#                                       embedding_Score2
# 0    [0.5429045557975769, -0.4305408000946045, 2.26...
# 1    [0.5429045557975769, -0.4305408000946045, 2.26...
# 2    [0.5429045557975769, -0.4305408000946045, 2.26...
# 3    [0.5429045557975769, -0.4305408000946045, 2.26...
# 4    [0.5429045557975769, -0.4305408000946045, 2.26...
# ..                                                 ...
# 99   [0.5429045557975769, -0.4305408000946045, 2.26...
# 100  [0.5429045557975769, -0.4305408000946045, 2.26...
# 101  [0.5429045557975769, -0.4305408000946045, 2.26...
# 102  [0.5429044961929321, -0.43053993582725525, 2.2...
# 103  [0.5429044961929321, -0.43053993582725525, 2.2...
#
# [104 rows x 10 columns]

# %%
## cosine similarity BERT
cosine_similarities = []
for i in range (len(X['embedding_Score'])):
    similarity = cosine_similarity([X['embedding_Score1'][i]],[X['embedding_Score'][i]])[0][0]
    cosine_similarities.append(similarity)
    X['similarity_BERT'][i] = cosine_similarities[i]
# Out:
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/2305458316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity_BERT'][i] = cosine_similarities[i]

# %%
print(X['similarity_BERT'])
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 99     0
# 100    0
# 101    0
# 102    0
# 103    0
# Name: similarity_BERT, Length: 104, dtype: int64

# %%
X['similarity2_BERT'] = 0
cosine_similarities2 = []

for i in range (len(X['embedding_Score'])):
    similarity2 = cosine_similarity([X['embedding_Score2'][i]],[X['embedding_Score'][i]])[0][0]
    cosine_similarities2.append(similarity2)
    X['similarity2_BERT'][i] = cosine_similarities2[i]
# Out:
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]
# C:\Users\agnes\AppData\Local\Temp/ipykernel_17928/1150114233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['similarity2_BERT'][i] = cosine_similarities2[i]

# %%
print(X['similarity2_BERT'])
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 99     0
# 100    0
# 101    0
# 102    0
# 103    0
# Name: similarity2_BERT, Length: 104, dtype: int64
